# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
# %matplotlib inline

x = np.arange(-10,11)

plt.figure(figsize=(12,6))
plt.title("Nice Shit")
plt.plot(x,x**2)
plt.plot(x,-1*(x**2))

# %%
plt.figure(figsize=(10,5)) #size of figure
plt.title("New Graph")  #figure title

plt.subplot(1,2,1)  #(row number,columns exist,choosen column)
plt.plot(x,x**2) #graph of x square
plt.plot([0,0,0],[-10,0,100])
plt.xlabel("X")
plt.ylabel("X Square")
# Out:
# Text(0, 0.5, 'X Square')
